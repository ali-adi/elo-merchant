# %%
import pandas as pd
import numpy as np

# %%
# Load the final dataset and test dataset from Parquet files
final_df = pd.read_parquet("../../datasets/final_dataset.parquet", engine="pyarrow")
test_df = pd.read_parquet("../../datasets/test.parquet", engine="pyarrow")

print("Datasets loaded.")
# Out:
# Datasets loaded.

# %%
# Display heads of both datasets
print("Head of final_df:")
display(final_df.head())

print("Head of test_df:")
display(test_df.head())
# Out:
# Head of final_df:
#            card_id  authorized_flag  city_id_x  category_1_x  installments  \
# 0  C_ID_5037ff576e                0        322             0             1
# 1  C_ID_5037ff576e                1        138             0             1
# 2  C_ID_5037ff576e                1        138             0             1
# 3  C_ID_5037ff576e                1        226             0             1
# 4  C_ID_5037ff576e                1        330             0             1
#
#    category_3  merchant_category_id_x  merchant_id  month_lag  \
# 0           1                     278       223191         -3
# 1           1                     307       311572         -4
# 2           1                     705       293697         -9
# 3           1                     307       137680         -4
# 4           1                     705        69949         -9
#
#    purchase_amount  ...  avg_purchases_lag12  active_months_lag12  category_4  \
# 0        -0.595260  ...             0.919680                 12.0           0
# 1         1.189469  ...             0.947394                 12.0           0
# 2        -0.640069  ...             1.021108                 12.0           0
# 3        -0.652256  ...             1.014457                 12.0           0
# 4        -0.674210  ...             1.026715                 12.0           0
#
#    city_id_y  state_id_y  category_2_y  feature_1  feature_2  feature_3  \
# 0       -1.0        11.0           3.0        5.0        1.0        1.0
# 1       -1.0        15.0           1.0        5.0        1.0        1.0
# 2       -1.0        15.0           1.0        5.0        1.0        1.0
# 3       -1.0        16.0           1.0        5.0        1.0        1.0
# 4       -1.0        17.0           3.0        5.0        1.0        1.0
#
#      target
# 0 -2.352713
# 1 -2.352713
# 2 -2.352713
# 3 -2.352713
# 4 -2.352713
#
# [5 rows x 39 columns]
# Head of test_df:
#            card_id  feature_1  feature_2  feature_3  authorized_flag  \
# 0  C_ID_0ab67a22ab          3          3          1                0
# 1  C_ID_0ab67a22ab          3          3          1                1
# 2  C_ID_0ab67a22ab          3          3          1                0
# 3  C_ID_0ab67a22ab          3          3          1                1
# 4  C_ID_0ab67a22ab          3          3          1                1
#
#    city_id_x  category_1_x  installments  category_3  merchant_category_id_x  \
# 0        235             0             1           1                     412
# 1        235             0             1           1                     278
# 2         -1             1             4           2                     879
# 3        235             0             1           1                      80
# 4        235             0             1           1                     278
#
#    ...  avg_sales_lag6  avg_purchases_lag6  active_months_lag6  \
# 0  ...            1.02            1.145868                 6.0
# 1  ...            1.13            1.105044                 6.0
# 2  ...            0.82            0.783000                 6.0
# 3  ...            1.13            1.115248                 6.0
# 4  ...            1.13            1.115248                 6.0
#
#    avg_sales_lag12  avg_purchases_lag12  active_months_lag12  category_4  \
# 0             0.94             1.116073                 12.0           0
# 1             1.07             1.050216                 12.0           0
# 2             0.65             0.584000                 12.0           1
# 3             1.09             1.073887                 12.0           0
# 4             1.09             1.073887                 12.0           0
#
#    city_id_y  state_id_y  category_2_y
# 0      235.0        12.0           1.0
# 1      235.0        12.0           1.0
# 2       -1.0        -1.0           1.0
# 3      235.0        12.0           1.0
# 4      235.0        12.0           1.0
#
# [5 rows x 38 columns]

# %%
# Print all columns in final_df and test_df

print("Columns in final_df:")
print(final_df.columns.tolist())

print("\nColumns in test_df:")
print(test_df.columns.tolist())
# Out:
# Columns in final_df:
# ['card_id', 'authorized_flag', 'city_id_x', 'category_1_x', 'installments', 'category_3', 'merchant_category_id_x', 'merchant_id', 'month_lag', 'purchase_amount', 'purchase_date', 'category_2_x', 'state_id_x', 'subsector_id_x', 'merchant_group_id', 'merchant_category_id_y', 'subsector_id_y', 'numerical_1', 'numerical_2', 'category_1_y', 'most_recent_sales_range', 'most_recent_purchases_range', 'avg_sales_lag3', 'avg_purchases_lag3', 'active_months_lag3', 'avg_sales_lag6', 'avg_purchases_lag6', 'active_months_lag6', 'avg_sales_lag12', 'avg_purchases_lag12', 'active_months_lag12', 'category_4', 'city_id_y', 'state_id_y', 'category_2_y', 'feature_1', 'feature_2', 'feature_3', 'target']
#
# Columns in test_df:
# ['card_id', 'feature_1', 'feature_2', 'feature_3', 'authorized_flag', 'city_id_x', 'category_1_x', 'installments', 'category_3', 'merchant_category_id_x', 'merchant_id', 'month_lag', 'purchase_amount', 'purchase_date', 'category_2_x', 'state_id_x', 'subsector_id_x', 'merchant_group_id', 'merchant_category_id_y', 'subsector_id_y', 'numerical_1', 'numerical_2', 'category_1_y', 'most_recent_sales_range', 'most_recent_purchases_range', 'avg_sales_lag3', 'avg_purchases_lag3', 'active_months_lag3', 'avg_sales_lag6', 'avg_purchases_lag6', 'active_months_lag6', 'avg_sales_lag12', 'avg_purchases_lag12', 'active_months_lag12', 'category_4', 'city_id_y', 'state_id_y', 'category_2_y']

# %%
# Reset index to ensure "card_id" is a column, not the index
final_df = final_df.reset_index()

# Define the desired column order based on the expected columns (target is the extra column in final_df)
col_order = ['card_id', 'authorized_flag', 'city_id_x', 'category_1_x', 'installments', 'category_3',
             'merchant_category_id_x', 'merchant_id', 'month_lag', 'purchase_amount', 'purchase_date',
             'category_2_x', 'state_id_x', 'subsector_id_x', 'merchant_group_id', 'merchant_category_id_y',
             'subsector_id_y', 'numerical_1', 'numerical_2', 'category_1_y', 'most_recent_sales_range',
             'most_recent_purchases_range', 'avg_sales_lag3', 'avg_purchases_lag3', 'active_months_lag3',
             'avg_sales_lag6', 'avg_purchases_lag6', 'active_months_lag6', 'avg_sales_lag12', 
             'avg_purchases_lag12', 'active_months_lag12', 'category_4', 'city_id_y', 'state_id_y', 
             'category_2_y', 'feature_1', 'feature_2', 'feature_3', 'target']

# Reorder final_df columns according to col_order
final_df = final_df[col_order]

# Print columns of final_df for verification
print("Final_df columns:")
print(final_df.columns.tolist())
# Out:
# Final_df columns:
# ['card_id', 'authorized_flag', 'city_id_x', 'category_1_x', 'installments', 'category_3', 'merchant_category_id_x', 'merchant_id', 'month_lag', 'purchase_amount', 'purchase_date', 'category_2_x', 'state_id_x', 'subsector_id_x', 'merchant_group_id', 'merchant_category_id_y', 'subsector_id_y', 'numerical_1', 'numerical_2', 'category_1_y', 'most_recent_sales_range', 'most_recent_purchases_range', 'avg_sales_lag3', 'avg_purchases_lag3', 'active_months_lag3', 'avg_sales_lag6', 'avg_purchases_lag6', 'active_months_lag6', 'avg_sales_lag12', 'avg_purchases_lag12', 'active_months_lag12', 'category_4', 'city_id_y', 'state_id_y', 'category_2_y', 'feature_1', 'feature_2', 'feature_3', 'target']

# %%
# Remove 'target' from the column order for test_df since test_df doesn't have it
test_col_order = [col for col in col_order if col != 'target']

# Reorder test_df columns to follow test_col_order
test_df = test_df[test_col_order]

# Print columns of test_df for verification
print("Test_df columns:")
print(test_df.columns.tolist())
# Out:
# Test_df columns:
# ['card_id', 'authorized_flag', 'city_id_x', 'category_1_x', 'installments', 'category_3', 'merchant_category_id_x', 'merchant_id', 'month_lag', 'purchase_amount', 'purchase_date', 'category_2_x', 'state_id_x', 'subsector_id_x', 'merchant_group_id', 'merchant_category_id_y', 'subsector_id_y', 'numerical_1', 'numerical_2', 'category_1_y', 'most_recent_sales_range', 'most_recent_purchases_range', 'avg_sales_lag3', 'avg_purchases_lag3', 'active_months_lag3', 'avg_sales_lag6', 'avg_purchases_lag6', 'active_months_lag6', 'avg_sales_lag12', 'avg_purchases_lag12', 'active_months_lag12', 'category_4', 'city_id_y', 'state_id_y', 'category_2_y', 'feature_1', 'feature_2', 'feature_3']

# %%
# Count unique card_ids in each dataframe
unique_final = final_df['card_id'].nunique()
unique_test = test_df['card_id'].nunique()

print(f"Number of unique card_id in final_df: {unique_final}")
print(f"Number of unique card_id in test_df: {unique_test}")
# Out:
# Number of unique card_id in final_df: 201917
# Number of unique card_id in test_df: 123623

# %%
# Get the sets of card_ids from both dataframes
final_card_ids = set(final_df['card_id'])
test_card_ids = set(test_df['card_id'])

# Find common card_ids
common_card_ids = final_card_ids.intersection(test_card_ids)

print(f"Number of common card_id between final_df and test_df: {len(common_card_ids)}")
# Optionally, display a sample of common card_ids
print("Sample common card_id values:")
print(list(common_card_ids)[:10])
# Out:
# Number of common card_id between final_df and test_df: 0
# Sample common card_id values:
# []

# %%
import numpy as np
import warnings

# Monkey-patch: if np.VisibleDeprecationWarning doesn't exist, assign it to DeprecationWarning
if not hasattr(np, 'VisibleDeprecationWarning'):
    np.VisibleDeprecationWarning = DeprecationWarning

import sweetviz as sv

# Drop card_id from the DataFrame for the report
df_profile = final_df.drop(columns=['card_id'], errors='ignore')

# Generate the report
report = sv.analyze(df_profile)
report.show_html("final_df_report.html")
# Out:
#                                              |                         | [  0%]   00:00 -> (? left)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[23], line 14
#      11 df_profile = final_df.drop(columns=['card_id'], errors='ignore')
#      13 # Generate the report
# ---> 14 report = sv.analyze(df_profile)
#      15 report.show_html("final_df_report.html")
#
# File ~/root/University/Y4S2/SC4000/project/code/env/lib/python3.13/site-packages/sweetviz/sv_public.py:12, in analyze(source, target_feat, feat_cfg, pairwise_analysis)
#       8 def analyze(source: Union[pd.DataFrame, Tuple[pd.DataFrame, str]],
#       9             target_feat: str = None,
#      10             feat_cfg: FeatureConfig = None,
#      11             pairwise_analysis: str = 'auto'):
# ---> 12     report = sweetviz.DataframeReport(source, target_feat, None,
#      13                                       pairwise_analysis, feat_cfg)
#      14     return report
#
# File ~/root/University/Y4S2/SC4000/project/code/env/lib/python3.13/site-packages/sweetviz/dataframe_report.py:301, in DataframeReport.__init__(self, source, target_feature_name, compare, pairwise_analysis, fc, verbosity)
#     299 self.progress_bar.reset(total=len(features_to_process))
#     300 self.progress_bar.set_description_str("[Step 2/3] Processing Pairwise Features")
# --> 301 self.process_associations(features_to_process, source_target_series, compare_target_series)
#     303 self.progress_bar.reset(total=1)
#     304 self.progress_bar.set_description_str("[Step 3/3] Generating associations graph")
#
# File ~/root/University/Y4S2/SC4000/project/code/env/lib/python3.13/site-packages/sweetviz/dataframe_report.py:472, in DataframeReport.process_associations(self, features_to_process, source_target_series, compare_target_series)
#     465         cur_associations_compare[other.source.name] = \
#     466             associations.theils_u(feature.compare, other.compare)
#     467 elif self[other.source.name]["type"] == FeatureType.TYPE_NUM:
#     468     # CAT-NUM
#     469     # This handles cat-num, then mirrors so no need to process num-cat separately
#     470     # (symmetrical relationship)
#     471     cur_associations[other.source.name] = \
# --> 472         associations.correlation_ratio(feature.source, other.source)
#     473     mirror_association(self._associations, feature_name, other.source.name, \
#     474                        cur_associations[other.source.name])
#     475     if process_compare:
#
# File ~/root/University/Y4S2/SC4000/project/code/env/lib/python3.13/site-packages/sweetviz/from_dython.py:229, in correlation_ratio(categories, measurements, nan_strategy, nan_replace_value)
#     226     categories, measurements = remove_incomplete_samples(
#     227         categories, measurements)
#     228 categories = convert(categories, 'array')
# --> 229 measurements = convert(measurements, 'array')
#     230 fcat, _ = pd.factorize(categories)
#     231 cat_num = np.max(fcat) + 1
#
# File ~/root/University/Y4S2/SC4000/project/code/env/lib/python3.13/site-packages/sweetviz/from_dython.py:59, in convert(data, to)
#      57     converted = data.values
#      58 elif isinstance(data, list):
# ---> 59     converted = np.array(data)
#      60 elif isinstance(data, pd.DataFrame):
#      61     converted = data.as_matrix()
#
# KeyboardInterrupt:
